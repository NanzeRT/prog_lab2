# %%
# !./gradlew jar
# Out:
# <=============> 100% CONFIGURING s]> Resolve dependencies of :app:runtimeClasspath<-------------> 0% EXECUTING s]> :app:compileJava<-------------> 0% EXECUTING s]<-------------> 0% EXECUTING s]<-------------> 0% EXECUTING s]<-------------> 0% EXECUTING s]<-------------> 0% EXECUTING s]<-------------> 0% EXECUTING s]<-------------> 0% EXECUTING s]<-------------> 0% EXECUTING s]<-------------> 0% EXECUTING [1s]<=========----> 75% EXECUTING [1s]> :app:jar
# BUILD SUCCESSFUL in 2s
# 2 actionable tasks: 2 executed
#
#
# <-------------> 0% WAITING> IDLE

# %%
# !cat app/build/libs/app.jar | helios "cat > app.jar"

# %%
# !helios "java -jar app.jar"
# Out:
# Stunky Мак♂semen♂ из команды полосатых вступает в бой!
# Blissey СпецнASS из команды красных вступает в бой!
# Stunky Мак♂semen♂ орёт на соперника.
# Blissey СпецнASS теряет 6 здоровья.
# Blissey СпецнASS уменьшает специальную атаку.
#
# Blissey СпецнASS присаживается, чтобы задуматься о своей жизни.
#
# Stunky Мак♂semen♂ орёт на соперника.
# Blissey СпецнASS теряет 6 здоровья.
# Blissey СпецнASS уменьшает специальную атаку.
#
# Blissey СпецнASS промахивается
#
# Stunky Мак♂semen♂ пукнул.
# Blissey СпецнASS отравлен
#
# Blissey СпецнASS сворачивает себе шею, повышая защиту.
# Blissey СпецнASS увеличивает защиту.
#
# Blissey СпецнASS теряет 37 здоровья.
# Stunky Мак♂semen♂ пукнул.
#
# Blissey СпецнASS промахивается
#
# Blissey СпецнASS теряет 37 здоровья.
# Stunky Мак♂semen♂ орёт на соперника.
# Blissey СпецнASS теряет 7 здоровья.
# Blissey СпецнASS уменьшает специальную атаку.
#
# Blissey СпецнASS присаживается, чтобы задуматься о своей жизни.
# Blissey СпецнASS
#
# ...
